# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.4icu.org/reviews/6191.htm'

# %%
page = requests.get(url)

# %%
page.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n<meta name="viewport" content="width=device-width, initial-scale=1"><meta http-equiv="X-UA-Compatible" content="IE=edge"/><!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script><![endif]-->\n<link rel="stylesheet" type="text/css" href="/_css/main.css?v=apr">\n<link rel="preconnect" href="https://csi.gstatic.com">\n<link rel="preconnect" href="https://securepubads.g.doubleclick.net">\n<link rel="preconnect" href="https://adservice.google.com/">\n<link rel="preconnect" href="https://googleads.g.doubleclick.net/">\n<link rel="preconnect" href="https://www.googletagservices.com/">\n<link rel="preconnect" href="https://tpc.googlesyndication.com/">\n<link rel="preconnect" href="https://cse.google.com/">\n<script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="IE=edge" http-equiv="X-UA-Compatible"><!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script><![endif]-->
# <link href="/_css/main.css?v=apr" rel="stylesheet" type="text/css"/>
# <link href="https://csi.gstatic.com" rel="preconnect"/>
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <link href="https://adservice.google.com/" rel="preconnect"/>
# <link href="https://googleads.g.doubleclick.net/" rel="preconnect"/>
# <link href="https://www.googletagservices.com/" rel="preconnect"/>
# <link href="https://tpc.googlesyndication.com/" rel="preconnect"/>
# <link href="https://cse.google.com/" rel="preconnect"/>
# ...

# %%
name = soup.findAll(attrs = {'class':'col-md-6 col-lg-8'})

# %%
name
# Out:
# [<div class="col-md-6 col-lg-8">
#  <h1 itemprop="name">University of Rochester</h1>
#  </div>]

# %%
overview = soup.findAll(attrs = {'class':'panel-heading'})

# %%
overview
# Out:
# [<div class="panel-heading">
#  <h2>University Overview</h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>Search Engine <sup><span class="label label-primary">New</span></sup></h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>University Identity</h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>University Location</h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>Study Areas and Degree Levels</h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>Yearly Tuition Range</h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>University Admissions</h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>Size and Profile</h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>Carnegie Classification <sup><span class="label label-primary">New</span></sup></h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>Facilities and Services</h2>
#  </div>,
#  <div class="panel-heading">
#  <h2>Accreditations</h2>
#  </div>,
#  <div class="panel-heading">
# ...

# %%
Panel = panel[0].text.replace('\n'," ")

# %%
panel = panel[1].text.replace('\n'," ")

# %%
heading = soup.find(attrs={'class':'panel-heading'}).text.replace('\n'," ")

# %%
heading
# Out:
# ' University Overview '

# %%
(soup.find(attrs={'class':'table borderless'}).text.replace('\n'," "))
# Out:
# '   Name University of Rochester   Acronym UR   Founded 1850    Motto Meliora Always Better   Colours Dandelion yellow and Rochester blue   Screenshot       '

# %%
data = [[url,Panel,panel,Ppanel,heading]]

# %%
data
# Out:
# [['https://www.4icu.org/reviews/6191.htm',
#   ' University Overview ',
#   [<div class="panel-heading">
#    <h2>University Overview</h2>
#    </div>,
#    <div class="panel-heading">
#    <h2>Search Engine <sup><span class="label label-primary">New</span></sup></h2>
#    </div>,
#    <div class="panel-heading">
#    <h2>University Identity</h2>
#    </div>,
#    <div class="panel-heading">
#    <h2>University Location</h2>
#    </div>,
#    <div class="panel-heading">
#    <h2>Study Areas and Degree Levels</h2>
#    </div>,
#    <div class="panel-heading">
#    <h2>Yearly Tuition Range</h2>
#    </div>,
#    <div class="panel-heading">
#    <h2>University Admissions</h2>
#    </div>,
#    <div class="panel-heading">
#    <h2>Size and Profile</h2>
#    </div>,
#    <div class="panel-heading">
#    <h2>Carnegie Classification <sup><span class="label label-primary">New</span></sup></h2>
#    </div>,
#    <div class="panel-heading">
#    <h2>Facilities and Services</h2>
#    </div>,
# ...

# %%
df = pd.DataFrame(data,columns = ['url','name','overview','heading','ans'])

# %%
df
# Out:
#                                      url                   name  \
# 0  https://www.4icu.org/reviews/6191.htm   University Overview
#
#               overview   heading                    ans
# 0   Search Engine New              University Overview
